# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/listings_clean.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      id                                             name  \
# 0           0  264776                      Huge Four Bedroom Apartment
# 1           1  264777                            One Bedroom Apartment
# 2           2  264778          Two Bedroom Newly Refurbished Apartment
# 3           3  264779                Refurbished Two Bedroom Apartment
# 4           4  264780  Spacious refurbished 2 bedroom apt with balcony
#
#    host_id host_name neighbourhood  latitude  longitude        room_type  \
# 0  1389063       Sue      Lewisham  51.44306   -0.01948  Entire home/apt
# 1  1389063       Sue      Lewisham  51.44284   -0.01997  Entire home/apt
# 2  1389063       Sue      Lewisham  51.44359   -0.02275  Entire home/apt
# 3  1389063       Sue      Lewisham  51.44355   -0.02309  Entire home/apt
# 4  1389063       Sue      Lewisham  51.44333   -0.02307  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  297.0               3                 68  2025-05-28               0.51
# 1   98.0               3                 24  2024-12-11               0.22
# 2  148.0               3                 58  2025-05-01               0.43
# 3  144.0               3                 36  2025-04-10               0.30
# 4  157.0               3                 54  2024-12-29               0.35
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                              11               293                     12
# 1                              11               318                      4
# 2                              11               302                      6
# 3                              11               328                      7
# 4                              11               255                      4
#
#    has_review  days_since_review
# 0        True               64.0
# 1        True              232.0
# 2        True               91.0
# 3        True              112.0
# 4        True              214.0

# %%
import re

# 1. (Re)load your cleaned data into `data`
# data = pd.read_csv("data/cleaned/listings_clean.csv")

# 2. Map number-words to integers
word_to_num = {
    "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
    "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10
}

# 3. Define the extraction function
def extract_bedroom_count(title: str) -> int:
    txt = title.lower()
    if "studio" in txt:
        return 0
    pattern = r'\b(\d+|' + '|'.join(word_to_num.keys()) + r')\b[\s-]*bedrooms?'
    match = re.search(pattern, txt)
    if match:
        val = match.group(1)
        return int(val) if val.isdigit() else word_to_num[val]
    return 1

# 4. Apply it
data['bedroom_count'] = data['name'].apply(extract_bedroom_count)

# %%
data.head(5)
# Out:
#    Unnamed: 0      id                                             name  \
# 0           0  264776                      Huge Four Bedroom Apartment
# 1           1  264777                            One Bedroom Apartment
# 2           2  264778          Two Bedroom Newly Refurbished Apartment
# 3           3  264779                Refurbished Two Bedroom Apartment
# 4           4  264780  Spacious refurbished 2 bedroom apt with balcony
#
#    host_id host_name neighbourhood  latitude  longitude        room_type  \
# 0  1389063       Sue      Lewisham  51.44306   -0.01948  Entire home/apt
# 1  1389063       Sue      Lewisham  51.44284   -0.01997  Entire home/apt
# 2  1389063       Sue      Lewisham  51.44359   -0.02275  Entire home/apt
# 3  1389063       Sue      Lewisham  51.44355   -0.02309  Entire home/apt
# 4  1389063       Sue      Lewisham  51.44333   -0.02307  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  297.0               3                 68  2025-05-28               0.51
# 1   98.0               3                 24  2024-12-11               0.22
# 2  148.0               3                 58  2025-05-01               0.43
# 3  144.0               3                 36  2025-04-10               0.30
# 4  157.0               3                 54  2024-12-29               0.35
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                              11               293                     12
# 1                              11               318                      4
# 2                              11               302                      6
# 3                              11               328                      7
# 4                              11               255                      4
#
#    has_review  days_since_review  bedroom_count
# 0        True               64.0              4
# 1        True              232.0              1
# 2        True               91.0              2
# 3        True              112.0              2
# 4        True              214.0              2

# %%
data = data.drop(["Unnamed: 0", "id", "name", "host_id", "host_name", "last_review"], axis=1)

# %%
# 1. Log transforms
data["log_price"]               = np.log1p(data["price"])
data["log_reviews_per_month"]   = np.log1p(data["reviews_per_month"])
data["log_reviews_ltm"]         = np.log1p(data["number_of_reviews_ltm"])
data["log_days_since_review"]   = np.log1p(data["days_since_review"])
data["log_host_listings"]       = np.log1p(data["calculated_host_listings_count"])

data = data.rename(columns={"neighbourhood": "borough"})

# %%
data.head()
# Out:
#     borough  latitude  longitude        room_type  price  minimum_nights  \
# 0  Lewisham  51.44306   -0.01948  Entire home/apt  297.0               3
# 1  Lewisham  51.44284   -0.01997  Entire home/apt   98.0               3
# 2  Lewisham  51.44359   -0.02275  Entire home/apt  148.0               3
# 3  Lewisham  51.44355   -0.02309  Entire home/apt  144.0               3
# 4  Lewisham  51.44333   -0.02307  Entire home/apt  157.0               3
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                 68               0.51                              11
# 1                 24               0.22                              11
# 2                 58               0.43                              11
# 3                 36               0.30                              11
# 4                 54               0.35                              11
#
#    availability_365  number_of_reviews_ltm  has_review  days_since_review  \
# 0               293                     12        True               64.0
# 1               318                      4        True              232.0
# 2               302                      6        True               91.0
# 3               328                      7        True              112.0
# 4               255                      4        True              214.0
#
#    bedroom_count  log_price  log_reviews_per_month  log_reviews_ltm  \
# 0              4   5.697093               0.412110         2.564949
# 1              1   4.595120               0.198851         1.609438
# 2              2   5.003946               0.357674         1.945910
# 3              2   4.976734               0.262364         2.079442
# 4              2   5.062595               0.300105         1.609438
#
#    log_days_since_review  log_host_listings
# 0               4.174387           2.484907
# 1               5.451038           2.484907
# 2               4.521789           2.484907
# 3               4.727388           2.484907
# 4               5.370638           2.484907

# %%
data = data.drop(["price", "reviews_per_month", "number_of_reviews_ltm", "days_since_review", "calculated_host_listings_count"], axis=1)

# %%
data.head()
# Out:
#     borough  latitude  longitude        room_type  minimum_nights  \
# 0  Lewisham  51.44306   -0.01948  Entire home/apt               3
# 1  Lewisham  51.44284   -0.01997  Entire home/apt               3
# 2  Lewisham  51.44359   -0.02275  Entire home/apt               3
# 3  Lewisham  51.44355   -0.02309  Entire home/apt               3
# 4  Lewisham  51.44333   -0.02307  Entire home/apt               3
#
#    number_of_reviews  availability_365  has_review  bedroom_count  log_price  \
# 0                 68               293        True              4   5.697093
# 1                 24               318        True              1   4.595120
# 2                 58               302        True              2   5.003946
# 3                 36               328        True              2   4.976734
# 4                 54               255        True              2   5.062595
#
#    log_reviews_per_month  log_reviews_ltm  log_days_since_review  \
# 0               0.412110         2.564949               4.174387
# 1               0.198851         1.609438               5.451038
# 2               0.357674         1.945910               4.521789
# 3               0.262364         2.079442               4.727388
# 4               0.300105         1.609438               5.370638
#
#    log_host_listings
# 0           2.484907
# 1           2.484907
# 2           2.484907
# 3           2.484907
# 4           2.484907

# %%
top_8_boroughs = data["borough"].value_counts().nlargest(8).index
data["borough_grouped"] = data["borough"].where(data["borough"].isin(top_8_boroughs), "Other")
dummies = pd.get_dummies(data, columns=["borough_grouped", "room_type"], prefix=["boro", "room"], drop_first=True)

# %%
dummies
# Out:
#              borough   latitude  longitude  minimum_nights  number_of_reviews  \
# 0           Lewisham  51.443060  -0.019480               3                 68
# 1           Lewisham  51.442840  -0.019970               3                 24
# 2           Lewisham  51.443590  -0.022750               3                 58
# 3           Lewisham  51.443550  -0.023090               3                 36
# 4           Lewisham  51.443330  -0.023070               3                 54
# ...              ...        ...        ...             ...                ...
# 62679  Tower Hamlets  51.525360  -0.072550               1                  0
# 62680        Hackney  51.543040  -0.076190              90                  0
# 62681    Westminster  51.518096  -0.168024               2                  0
# 62682    Westminster  51.496230  -0.133060               1                  0
# 62683    Westminster  51.519280  -0.200610               2                  0
#
#        availability_365  has_review  bedroom_count  log_price  \
# 0                   293        True              4   5.697093
# 1                   318        True              1   4.595120
# 2                   302        True              2   5.003946
# 3                   328        True              2   4.976734
# 4                   255        True              2   5.062595
# ...                 ...         ...            ...        ...
# 62679               365       False              1   7.241366
# 62680               361       False              0   4.564348
# 62681               359       False              1   5.703782
# 62682               365       False              1   8.006701
# 62683                63       False              2   4.890349
#
#        log_reviews_per_month  ...  boro_Kensington and Chelsea  boro_Lambeth  \
# 0                   0.412110  ...                        False         False
# 1                   0.198851  ...                        False         False
# 2                   0.357674  ...                        False         False
# 3                   0.262364  ...                        False         False
# 4                   0.300105  ...                        False         False
# ...                      ...  ...                          ...           ...
# 62679               0.000000  ...                        False         False
# 62680               0.000000  ...                        False         False
# 62681               0.000000  ...                        False         False
# 62682               0.000000  ...                        False         False
# 62683               0.000000  ...                        False         False
#
#        boro_Other  boro_Southwark  boro_Tower Hamlets  boro_Wandsworth  \
# 0            True           False               False            False
# 1            True           False               False            False
# 2            True           False               False            False
# 3            True           False               False            False
# 4            True           False               False            False
# ...           ...             ...                 ...              ...
# 62679       False           False                True            False
# 62680       False           False               False            False
# 62681       False           False               False            False
# 62682       False           False               False            False
# 62683       False           False               False            False
#
#        boro_Westminster  room_Hotel room  room_Private room  room_Shared room
# 0                 False            False              False             False
# 1                 False            False              False             False
# 2                 False            False              False             False
# 3                 False            False              False             False
# 4                 False            False              False             False
# ...                 ...              ...                ...               ...
# 62679             False            False              False             False
# 62680             False            False              False             False
# 62681              True            False              False             False
# 62682              True            False              False             False
# 62683              True            False              False             False
#
# [62684 rows x 24 columns]

# %%
data = pd.concat([data, dummies], axis=1)

# %%
data = data.drop(["borough", "room_type", "borough_grouped"], axis=1)

# %%
data = data.fillna(0)

# %%
import sklearn as sk

# %%
y = data["log_price"]
X = data.drop(columns="log_price")
RAND_SEED = 42

# %%
bool_cols = X.select_dtypes(include="bool").columns
dtype_map = {col: "int64" for col in bool_cols}
X = X.astype(dtype_map)

# %%
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, test_size=0.2, random_state=RAND_SEED)

# %%
# Ridge

ridge = sk.linear_model.Ridge(alpha=1.0, random_state=RAND_SEED)
ridge.fit(X_train, y_train)

y_pred_ridge = ridge.predict(X_test)
print(f"Ridge RMSE: {sk.metrics.mean_squared_error(y_test, y_pred_ridge)}")
print(f"Ridge R²: {sk.metrics.r2_score(y_test, y_pred_ridge)}")
# Out:
# Ridge RMSE: 0.31220393716969674
# Ridge R²: 0.5223781392634553

# %%
# Random Forest Regressor

rf = sk.ensemble.RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    min_samples_leaf=5,
    random_state=RAND_SEED,
    n_jobs=-1
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)
print("RF RMSE:", sk.metrics.mean_squared_error(y_test, y_pred_rf))
print("RF R²:  ", sk.metrics.r2_score(y_test, y_pred_rf))
# Out:
# RF RMSE: 0.22634712889779435
# RF R²:   0.6537252609412886

# %%
# Feature Importance

# %%
# Ridge Hyperparameter Tuning

# %%
# Random Forest Regressor Hyperparameter Tuning

# %%
# Gradient Boosting
